# %% [markdown]
# # Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You
# have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10
# jobs data.
# This task will be done in following steps:
#
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Analyst” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the
# location” field.
# 3. Then click the searchbutton.
# 4. Then scrape the data for the first 10 jobs results youget.
# 5. Finally create a dataframe of the scraped data

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\ajayk\anaconda3\lib\site-packages (4.9.1)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\ajayk\anaconda3\lib\site-packages (from selenium) (2022.9.14)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\ajayk\anaconda3\lib\site-packages (from selenium) (1.26.11)
# Requirement already satisfied: trio~=0.17 in c:\users\ajayk\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\ajayk\anaconda3\lib\site-packages (from selenium) (0.10.2)
# Requirement already satisfied: outcome in c:\users\ajayk\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: idna in c:\users\ajayk\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\ajayk\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\ajayk\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.1)
# Requirement already satisfied: cffi>=1.14 in c:\users\ajayk\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: async-generator>=1.9 in c:\users\ajayk\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: sortedcontainers in c:\users\ajayk\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: sniffio in c:\users\ajayk\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\ajayk\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\ajayk\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\ajayk\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\ajayk\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
#lets first connect to the druver
driver=webdriver.Chrome(r"Chromedriver.exe")

# %%
# open the naukri page on automated chrome browser
driver.get("https://www.naukri.com/")

# %%
# entering designation and location as required in question

designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Analyst')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/div[1]/div/input")
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
# scrraping job title from given page
title_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)

# %%
# scrraping job Location from given page
location_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)

# %%
# scrraping company name from given page
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)

# %%
# scrraping job experience from given page
experience_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience_tags[0:10]:
    experience=i.text
    experience_required.append(experience)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
import pandas as pd
df=pd.DataFrame({'Title':job_title,'Location':job_location,'Company_name':company_name,'Experience':experience_required})
df
# Out:
#                                Title  \
# 0                   DATA ANALYST III
# 1                       Data Analyst
# 2          Online Data Analyst India
# 3                       Data Analyst
# 4                       Data Analyst
# 5  Procurement Analyst/ Data Analyst
# 6             Data Analyst - FinTech
# 7        Data Engineer/ Data Analyst
# 8                       Data Analyst
# 9                       Data Analyst
#
#                                             Location  \
# 0                                Bangalore/Bengaluru
# 1                                Bangalore/Bengaluru
# 2  Bangalore/Bengaluru, Kolkata, Mumbai, New Delh...
# 3                   Bangalore/Bengaluru(Anepalya +1)
# 4                    Bangalore/ Bengaluru, Karnataka
# 5      Bangalore/ Bengaluru, Karnataka(Rajaji Nagar)
# 6  Bangalore/Bengaluru, Mumbai, Hyderabad/Secunde...
# 7  Hybrid - Bangalore/Bengaluru, Kolkata, Pune, A...
# 8  Hybrid - Bangalore/ Bengaluru, Karnataka, Noid...
# 9  Bangalore/Bengaluru, Kolkata, Mumbai, New Delh...
#
#                Company_name Experience
# 0                   Walmart    7-9 Yrs
# 1      Paychex It Solutions    3-8 Yrs
# 2       TELUS International    1-4 Yrs
# 3               Eastvantage    4-7 Yrs
# 4  Mensa Brand Technologies    1-2 Yrs
# 5        Bloom Energy India    6-7 Yrs
# 6              Primo Hiring    1-2 Yrs
# 7    Careernet Technologies   6-11 Yrs
# 8                       EXL    2-7 Yrs
# 9   Arise Virtual Solutions    4-5 Yrs

# %% [markdown]
# # Q2:Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location.
#
# You have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.
# This task will be done in following steps:
#
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Scientist” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the
# location” field.
# 3. Then click the searchbutton.
# 4. Then scrape the data for the first 10 jobs results youget.
# 5. Finally create a dataframe of the scraped data

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\\Users\\ajayk\\chromedriver.exe")

# %%
#lets first connect to the druver
driver=webdriver.Chrome(r"Chromedriver.exe")

# %%
# open the naukri page on automated chrome browser
driver.get("https://www.naukri.com/")

# %%
# entering designation and location as required in question

designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[7]/div/div/div[5]/div/div/div/div[1]/div/input")
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")

# %%
job_title=[]
job_location=[]
company_name=[]

# %%
# scrraping job title from given page
title_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)

# %%
# scrraping company name from given page
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)

# %%
# scrraping job Location from given page
location_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)

# %%
print(len(job_title),len(job_location),len(company_name))
# Out:
# 10 10 10

# %%
import pandas as pd
df=pd.DataFrame({'Title':job_title,'Location':job_location,'Company_name':company_name})
df
# Out:
#                                                Title  \
# 0                   Analystics & Modeling Specialist
# 1                    Machine Learning (AI) Architect
# 2  ACN - Applied Intelligence - Finance - Data Sc...
# 3                              Senior Data Scientist
# 4           Data Scientist || Immediate Joiners Only
# 5                            Data Science consultant
# 6                                     Data Scientist
# 7                              Senior Data Scientist
# 8                                     Data Scientist
# 9            Director/Senior Director - Data Science
#
#                                             Location         Company_name
# 0  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...            Accenture
# 1  Bangalore/Bengaluru, Kolkata, Mumbai, New Delh...           Persistent
# 2  Bangalore/Bengaluru, Hyderabad/Secunderabad, P...            Accenture
# 3                        Bangalore/Bengaluru, Mumbai    Fractal Analytics
# 4                    Bangalore/ Bengaluru, Karnataka             Sun Life
# 5                                Bangalore/Bengaluru            Accenture
# 6  Bangalore/Bengaluru, Kolkata, Mumbai, New Delh...   KAS Services India
# 7  Bangalore/Bengaluru, Kolkata, Mumbai, New Delh...  Stats Systems India
# 8                          Bangalore/Bengaluru, Pune  Rockwell Automation
# 9  Bangalore/Bengaluru, Noida, Hyderabad/Secunder...         Axtria India

# %% [markdown]
# # Q3: In this question you have to scrape data using the filters available on the webpage as shown below:
# ASSIGNMENT 2
#
# You have to use the location and salary filter.
# You have to scrape data for “Data Scientist” designation for first 10 job results.
# You have to scrape the job-title, job-location, company name, experience required.
# The location filter to be used is “Delhi/NCR”. The salary filter to be used is “3-6” lakhs
# The task will be done as shown in the below steps:
# 1. first get thewebpage https://www.naukri.com/
# 2. Enter “Data Scientist” in “Skill, Designations, and Companies” field.
# 3. Then click the searchbutton.
# 4. Then apply the location filter and salary filter by checking the respectiveboxes
# 5. Then scrape the data for the first 10 jobs results youget.
# 6. Finally create a dataframe of the scrapeddata.
# Note: All of the above steps have to be done in code. No step is to be done manuall

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\\Users\\ajayk\\chromedriver.exe")

# %%
# open the naukri page on automated chrome browser
driver.get("https://www.naukri.com/")

# %%
# entering designation and location as required in question

designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[7]/div/div/div[5]/div/div/div/div[1]/div/input")
location.send_keys('Delhi/NCR')

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]
job_salary=[]

# %%
# scrraping job title from given page
title_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)

# %%
# scrraping company name from given page
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)

# %%
# scrraping job Location from given page
location_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)

# %%
# scrraping job experience from given page
experience_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience_tags[0:10]:
    experience=i.text
    experience_required.append(experience)

# %%
# scrraping job Location from given page
salary_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft "]')
for i in salary_tags[0:10]:
    salary=i.text
    job_salary.append(salary)

# %%
print(len(job_title),len(job_location),len(company_name),len(job_salary),len(experience_required))
# Out:
# 10 10 10 10 10

# %%
import pandas as pd
df=pd.DataFrame({'Title':job_title,'Location':job_location,'Company_name':company_name,'Experience':experience_required,'Salary':job_salary})
df
# Out:
#                                                Title  \
# 0                    Machine Learning (AI) Architect
# 1  ACN - Applied Intelligence - Finance - Data Sc...
# 2                                     Data Scientist
# 3                              Senior Data Scientist
# 4            Director/Senior Director - Data Science
# 5              Manager/Senior Manager - Data Science
# 6                                     Data Scientist
# 7                               Data Scientist (CPG)
# 8               Data Scientist - Consultant (Retail)
# 9               Data Scientist - Consultant (Retail)
#
#                                             Location         Company_name  \
# 0  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...           Persistent
# 1  Hyderabad/Secunderabad, Pune, Chennai, Gurgaon...            Accenture
# 2  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...   KAS Services India
# 3  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...  Stats Systems India
# 4  Noida, Hyderabad/Secunderabad, Pune, Gurgaon/G...         Axtria India
# 5  Noida, Hyderabad/Secunderabad, Pune, Gurgaon/G...         Axtria India
# 6              Noida, New Delhi, Bangalore/Bengaluru  Rockwell Automation
# 7  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...             Tredence
# 8  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...             Tredence
# 9  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...             Tredence
#
#   Experience         Salary
# 0   5-12 Yrs  Not disclosed
# 1    2-7 Yrs  Not disclosed
# 2    3-5 Yrs  Not disclosed
# 3    3-7 Yrs  Not disclosed
# 4  10-15 Yrs  Not disclosed
# 5   8-12 Yrs  Not disclosed
# 6    3-7 Yrs  Not disclosed
# 7    2-4 Yrs  Not disclosed
# 8    2-4 Yrs  Not disclosed
# 9    2-4 Yrs  Not disclosed

# %% [markdown]
# # Q4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
#
# 1. Brand
# 2. ProductDescription
# 3. Price
# As shown in the below image, you have to scrape the above attributes.
# ASSIGNMENT 2
# 4. After scraping data from the first page, go to the “Next” Button at the bottom other page , then
# click on it.
# 5. Now scrape data from this page asusual
# 6. Repeat this until you get data for 100sunglasses.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\\Users\\ajayk\\chromedriver.exe")

# %%
# open the naukri page on automated chrome browser
driver.get("https://www.flipkart.com/")

# %%
sunglasses=driver.find_element(By.CLASS_NAME,"_3704LK")
sunglasses.send_keys('sunglasses')

# %%
search=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

# %%
brand=[]
prod_desciption=[]
price=[]
time.sleep(3)

# %%
# Scraping Data for different Attributes-
start=0
end=3
for page in range(start,end):
    brands=driver.find_elements(By.XPATH,"//div[@class='_2WkVRV']")
    for i in brands[0:100]:
        brand.append(i.text)
    Product_desc=driver.find_elements(By.XPATH,"//a[@class='IRpwTa']")
    for i in Product_desc[0:100]:
        prod_desciption.append(i.text)    
    prices=driver.find_elements(By.XPATH,"//div[@class='_30jeq3']")
    for i in prices[0:100]:
        price.append(i.text)
    next_button=driver.find_elements(By.XPATH,"//a[@class='_1LKTO3']")

# %%
#checking length for all attributes-
print(len(brand),len(prod_desciption),len(price))
# Out:
# 120 117 120

# %%
# Creating Dataframe-
df=pd.DataFrame({'Brand':brand[0:100],'Prod_desc':prod_desciption[0:100],'Price':price[0:100]})
df
# Out:
#                     Brand                                          Prod_desc  \
# 0              iCopertina      UV Protection Wayfarer Sunglasses (Free Size)
# 1            Silver Kartz              UV Protection Aviator Sunglasses (50)
# 2               Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...
# 3                   SDEEP  UV Protection, Others Spectacle Sunglasses (Fr...
# 4                Fastrack   UV Protection Rectangular Sunglasses (Free Size)
# ..                    ...                                                ...
# 95         kingsunglasses  Polarized, UV Protection Rectangular Sunglasse...
# 96  HRX by Hrithik Roshan         UV Protection Retro Square Sunglasses (32)
# 97          VINCENT CHASE          UV Protection Rectangular Sunglasses (56)
# 98              AVNISALES  UV Protection, Riding Glasses Retro Square, Re...
# 99               Fastrack  UV Protection Retro Square Sunglasses (Free Size)
#
#      Price
# 0     ₹197
# 1     ₹263
# 2     ₹168
# 3     ₹185
# 4     ₹549
# ..     ...
# 95    ₹265
# 96  ₹1,386
# 97  ₹1,199
# 98    ₹247
# 99    ₹549
#
# [100 rows x 3 columns]

# %%
driver.close()

# %% [markdown]
# Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone.
#
# You have to go the
#
# link: https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&marketplace=FLIPKART. you have to scrape the below mention attributes. These are
#
# Rating
# Review_summary
# Full review
# You have to scrape this data for first 100 reviews

# %%
driver=webdriver.Chrome(r"Chromedriver.exe")

# %%
driver.get(" https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&marketplace=FLIPKART")

# %%
#checking length for all attributes-
urls=[]
short_review=[]
complete_review=[]
stars=[]
time.sleep(2)

# %%
url_1 = driver.find_elements(By.XPATH,"//a[@class='ge-49M _2Kfbh8']")
for i in url_1:
    urls.append(i.get_attribute('href'))
url_2 = driver.find_elements(By.XPATH,"//a[@class='ge-49M']")
for i in url_2:
    urls.append(i.get_attribute('href'))
time.sleep(4)

# %%
for i in urls:
    driver.get(i)
    #for scrapping the number of stars
    for j in driver.find_elements(By.XPATH,"//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
        stars.append(j.text)
    #for scrapping the short review
    for k in driver.find_elements(By.XPATH,"//p[@class='_2-N8zT']"):
        short_review.append(k.text)
    #for scrapping the complete review
    for l in driver.find_elements(By.XPATH,"//div[@class='t-ZTKy']/div/div"):
        complete_review.append(l.text)

# %%
print(len(stars),len(short_review),len(complete_review))
# Out:
# 10 10 10

# %%
df=pd.DataFrame({'Rating':stars,'Review_summary':short_review,'Full_summary':complete_review})
df
# Out:
#   Rating     Review_summary                                       Full_summary
# 0      5          Wonderful                             This is amazing at all
# 1      5     Classy product  Camera is awesome\nBest battery backup\nA perf...
# 2      5             Super!                        Good product 👌I love iPhone
# 3      5           Terrific                                     Very very good
# 4      5          Must buy!                                It’s really awesome
# 5      5  Terrific purchase                                  Value for money 😍
# 6      5   Perfect product!                                         V Good all
# 7      5          Must buy!  Go for iPhone 11 , if confused between iPhone ...
# 8      5          Brilliant                                   Excellent Phone.
# 9      5          Brilliant                           very good camera quality

# %% [markdown]
# Q6:Scrape data for first 100 sneakers you find when you visit flipkart.comand search for “sneakers” in the search field.You have to scrape 3 attributes of each sneaker :
#
# Brand
# Product Description
# Price
# Also note that all the steps required during scraping should be done through code only and not manually.

# %%
driver=webdriver.Chrome(r"Chromedriver.exe")

# %%
driver.get("https://www.flipkart.com/")

# %%
# Entering sneakers in search box-
sneakers=driver.find_element(By.CLASS_NAME,"_3704LK")
sneakers.send_keys('sneakers')

#Clicking on Search Button-
search=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

# %%
brand=[]
description=[]
price=[]

# %%
# Scraping Data for different Attributes-
start=0
end=4
for page in range(start,end):#for loop for scrapping 4 page
    brands=driver.find_elements(By.CLASS_NAME,'_2WkVRV')#scraping brands name by class name='_2WkVRV'
    for i in brands:
        brand.append(i.text)#appending the text in Brand list
    prices=driver.find_elements(By.XPATH,"//div[@class='_30jeq3']")# scraping the price from the xpath
    for i in prices:
        price.append(i.text)
    desc=driver.find_elements(By.XPATH,'//a[@class="IRpwTa" or @class="IRpwTa _2-ICcC"]')#scraping description from the xpath
    for i in desc:
        description.append(i.text)
        
    nxt_button=driver.find_elements(By.XPATH,"//a[@class='_1LKTO3']")#scraping the list of buttons from the page
    try:
        driver.get(nxt_button[1].get_attribute('href'))#getting the link from the list for next page
    except:
        driver.get(nxt_button[0].get_attribute('href'))

# %%
print(len(brand),len(description),len(price))
# Out:
# 160 160 160

# %%
# Creating Dataframe-
df=pd.DataFrame({'Brand':brand,'Prod_desc':description,'Price':price})
df
# Out:
#                Brand                                          Prod_desc  \
# 0             BRUTON      Modern Trendy Sneakers Shoes Sneakers For Men
# 1             BRUTON      Modern Trendy Sneakers Shoes Sneakers For Men
# 2               aadi  Lightweight,Comfort,Summer,Trendy,Walking,Outd...
# 3               aadi                                   Sneakers For Men
# 4             BRUTON               Modern Trendy Shoes Sneakers For Men
# ..               ...                                                ...
# 155     Robbie jones  Casual Sneakers Shoes For Men And Boys Sneaker...
# 156          BIG FOX  Latest Design Beta-5 Sneakers and Training Sho...
# 157      bacca bucci  Cross Trainer Mid-Top Sporty Chunky Sneakers f...
# 158              SFR                                   Sneakers For Men
# 159  U.S. POLO ASSN.                           CLARKIN Sneakers For Men
#
#       Price
# 0      ₹279
# 1      ₹299
# 2      ₹249
# 3      ₹299
# 4      ₹249
# ..      ...
# 155    ₹394
# 156    ₹899
# 157  ₹1,599
# 158    ₹249
# 159  ₹1,499
#
# [160 rows x 3 columns]

# %%
driver.close()

# %% [markdown]
# Q7:  Go to webpage https://www.amazon.in/Enter “Laptop” in the search field and then click the search icon.Then set CPU Type filter to “Intel Core i7”
# After setting the filters scrape first 10 laptops data.You have to scrape 3 attributes for each laptop:
# 1. title
# 2. Ratings
# 3. Price# 8)Amazon Laptop

# %%
driver=webdriver.Chrome(r"Chromedriver.exe")

# %%
driver.get("https://www.amazon.in/")

# %%
laptop=driver.find_element(By.XPATH,"//div[@class='nav-search-field ']//input")
laptop.send_keys('Laptop')

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input")
search.click()

# %%
#Creating Empty List for different attributes-
Title=[]
price=[]
Ratings=[]
Rating=[]

# %%
start=0
end=1
for page in range(start,end):
    title=driver.find_elements(By.XPATH,"//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-2']")
    for i in title[0:10]:
        Title.append(i.text) 
    prices=driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
    for i in prices[0:10]:
        price.append(i.text)

# %%
titles_rat=driver.find_elements(By.XPATH,"//div[@class='a-row a-size-small']/span")
for i in titles_rat:
    Rating.append(i.get_attribute("aria-label"))
rating=[]
for i in range(0,len(Rating))[0:20]:
    if i == 0 or  i/2 == i//2:
        rating.append(Rating[i][0:3])

# %%
#checking length for all attributes-
print(len(Title),len(price),len(rating))
# Out:
# 10 10 10

# %%
# Creating Dataframe-
df=pd.DataFrame({'Title':Title,'Price':price,'Ratings':rating})
df
# Out:
#                                                Title   Price Ratings
# 0  Dell Vostro 3420 Laptop, Intel i3-1115G4/8GB D...  51,990     4.0
# 1  Dell 14, Intel 12th Gen i5-1235U Laptop/8GB/51...  53,990     3.6
# 2  Xiaomi Notebook Pro Max 11th Gen Intel Core i5...  35,990     4.3
# 3  Lenovo IdeaPad Slim 3 Intel Core i3 11th Gen 1...  53,490     4.1
# 4  Lenovo V15 Intel Celeron N4500 15.6" (39.62 cm...  46,999     3.9
# 5  MSI GF63 Thin, Intel Core i7-11800H, 40CM FHD ...  36,990     4.0
# 6  HP Laptop 15s, Intel Celeron N4500, 15.6 inch(...  23,490     4.1
# 7  Lenovo IdeaPad Slim 3 Intel Core i3-1115G4 11t...  34,990     4.2
# 8  Xiaomi Notebook Ultra Max 11th Gen Intel Core ...  65,490     4.1
# 9  HP Laptop 15s, 11th Gen Intel Core i3-1115G4, ...  39,490     4.1

# %%
driver.close()

# %% [markdown]
# Q8- Scrap Top 1000 Quotes Of All Time This task will be done in following steps:
#
# 1.First get the webpage https://www.azquotes.com/
# 2. Click on Top Quotes
# 3. Than scrap
#
# a) Quote
# b) Author
# c) Type Of Quote

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import time
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains

# %%
driver=webdriver.Chrome(r"Chromedriver.exe")

# %%
driver.get('https://www.azquotes.com/')

# %%
search_button=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div[1]/div/div[3]/ul/li[5]/a")
search_button.click()

# %%
Quote=[]
Author=[]
type_of_quote=[]

Details=[i.text.split('\n') for i in driver.find_elements(By.XPATH,"//div[@class='wrap-block']")]

for i in Details:
    Quote.append(i[0])
    Author.append(i[1])
    type_of_quote.append(i[2])

# %%
data=pd.DataFrame({'Quotes':Quote,'Author':Author,'Type of quote':type_of_quote })
data
# Out:
#                                                Quotes                Author  \
# 0   The essence of strategy is choosing what not t...        Michael Porter
# 1   One cannot and must not try to erase the past ...            Golda Meir
# 2   Patriotism means to stand by the country. It d...    Theodore Roosevelt
# 3   Death is something inevitable. When a man has ...        Nelson Mandela
# 4   You have to love a nation that celebrates its ...          Erma Bombeck
# ..                                                ...                   ...
# 95     When the going gets weird, the weird turn pro.    Hunter S. Thompson
# 96  When a train goes through a tunnel and it gets...       Corrie Ten Boom
# 97  If you think you are too small to make a diffe...            Dalai Lama
# 98  God doesn't require us to succeed, he only req...         Mother Teresa
# 99    Change your thoughts and you change your world.  Norman Vincent Peale
#
#                                Type of quote
# 0   Essence, Deep Thought, Transcendentalism
# 1                  Inspiration, Past, Trying
# 2                        Country, Peace, War
# 3         Inspirational, Motivational, Death
# 4               4th Of July, Food, Patriotic
# ..                                       ...
# 95                    Music, Sports, Hunting
# 96             Trust, Encouraging, Uplifting
# 97              Inspirational, Funny, Change
# 98                      Success, God, Mother
# 99       Inspirational, Motivational, Change
#
# [100 rows x 3 columns]

# %% [markdown]
# 9. write python program to display list of respected former Prime Ministers of India(i.e. Name, Born-Dead, Term of office, Remarks) from https://www.jagranjosh.com/.
#
# This task will be done in following steps:
# 1. First get the webpage https://www.jagranjosh.com/
# 2. Then You have to click on the GK option
# 3. Then click on the List of all Prime Ministers of India
# 4. Then scrap the mentioned data and make the DataFrame

# %%
driver=webdriver.Chrome(r"Chromedriver.exe")

# %%
url = "https://www.jagranjosh.com/"
driver.get(url)

# %%
gk_btn = driver.find_element(By.XPATH,'//*[@id="1540978020504"]/div[1]/header/div[3]/ul/li[9]/a')
gk_btn.click()

# %%
pm_btn = driver.find_element(By.XPATH,'//*[@id="popluarGK"]/ul/li[2]/a')
pm_btn.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18028\650142215.py in <module>
# ----> 1 pm_btn = driver.find_element(By.XPATH,'//*[@id="popluarGK"]/ul/li[2]/a')
#       2 pm_btn.click()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     829             value = f'[name="{value}"]'
#     830
# --> 831         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     832
#     833     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     438         response = self.command_executor.execute(driver_command, params)
#     439         if response:
# --> 440             self.error_handler.check_response(response)
#     441             response["value"] = self._unwrap_value(response.get("value", None))
#     442             return response
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     243                 alert_text = value["alert"].get("text")
#     244             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245         raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="popluarGK"]/ul/li[2]/a"}
#   (Session info: chrome=114.0.5735.199)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00868893+48451]
# 	(No symbol) [0x007FB8A1]
# 	(No symbol) [0x00705058]
# 	(No symbol) [0x00730467]
# 	(No symbol) [0x0073069B]
# 	(No symbol) [0x0075DD92]
# 	(No symbol) [0x0074A304]
# 	(No symbol) [0x0075C482]
# 	(No symbol) [0x0074A0B6]
# 	(No symbol) [0x00727E08]
# 	(No symbol) [0x00728F2D]
# 	GetHandleVerifier [0x00AC8E3A+2540266]
# 	GetHandleVerifier [0x00B08959+2801161]
# 	GetHandleVerifier [0x00B0295C+2776588]
# 	GetHandleVerifier [0x008F2280+612144]
# 	(No symbol) [0x00804F6C]
# 	(No symbol) [0x008011D8]
# 	(No symbol) [0x008012BB]
# 	(No symbol) [0x007F4857]
# 	BaseThreadInitThunk [0x769F7D59+25]
# 	RtlInitializeExceptionChain [0x77E5B79B+107]
# 	RtlClearBits [0x77E5B71F+191]

# %%
Name= []
Born_Dead = []
Terms_of_office = []
Remarks = []

# %%
#name
names = driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[2]/p')
for name in names:
    Name.append(name.text)
    

#borndead
born_dead = driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[3]/p')
for i in born_dead:
    Born_Dead.append(i.text)
    

#terms_of_office
terms_of_office = driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[4]')
for i in terms_of_office:
    Terms_of_office.append(i.text.replace('\n', ''))
    
    
#Remarks
remarks = driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[5]/p')
for i in remarks:
    Remarks.append(i.text)

# %%
len(Name),len(Born_Dead),len(Terms_of_office),len(Remarks)
# Out:
# (19, 19, 19, 19)

# %%
df=pd.DataFrame({"Names":Name,"Born-Dead":Born_Dead,"Term of office":Terms_of_office,
                "Remarks":Remarks})
df
# Out:
#                           Names     Born-Dead  \
# 0             Jawahar Lal Nehru   (1889–1964)
# 1     Gulzarilal Nanda (Acting)   (1898-1998)
# 2           Lal Bahadur Shastri   (1904–1966)
# 3   Gulzari Lal Nanda  (Acting)   (1898-1998)
# 4                 Indira Gandhi   (1917–1984)
# 5                 Morarji Desai   (1896–1995)
# 6                  Charan Singh   (1902–1987)
# 7                 Indira Gandhi   (1917–1984)
# 8                  Rajiv Gandhi   (1944–1991)
# 9                   V. P. Singh   (1931–2008)
# 10              Chandra Shekhar   (1927–2007)
# 11          P. V. Narasimha Rao   (1921–2004)
# 12         Atal Bihari Vajpayee  (1924- 2018)
# 13             H. D. Deve Gowda   (born 1933)
# 14           Inder Kumar Gujral   (1919–2012)
# 15         Atal Bihari Vajpayee   (1924-2018)
# 16               Manmohan Singh   (born 1932)
# 17                Narendra Modi   (born 1950)
# 18                Narendra Modi   (born 1950)
#
#                                        Term of office  \
# 0     15 August 1947 to 27 May 196416 years, 286 days
# 1                  27 May 1964 to 9 June 1964,13 days
# 2      9 June 1964 to 11 January 19661 year, 216 days
# 3           11 January 1966 to 24 January 196613 days
# 4   24 January 1966 to 24 March 197711 years, 59 days
# 5     24 March 1977 to  28 July 1979 2 year, 126 days
# 6             28 July 1979 to 14 January 1980170 days
# 7   14 January 1980 to 31 October 19844 years, 291...
# 8   31 October 1984 to 2 December 19895 years, 32 ...
# 9         2 December 1989 to 10 November 1990343 days
# 10           10 November 1990 to 21 June 1991223 days
# 11       21 June 1991 to 16 May 19964 years, 330 days
# 12                  16 May 1996 to 1 June 199616 days
# 13               1 June 1996 to 21 April 1997324 days
# 14            21 April 1997 to 19 March 1998 332 days
# 15      19 March 1998 to 22 May 2004 6 years, 64 days
# 16      22 May 2004 to 26 May 2014   10 years, 4 days
# 17                                 26 May 2014 - 2019
# 18                             30 May 2019- Incumbent
#
#                                               Remarks
# 0   The first prime minister of India and the long...
# 1                            First acting PM of India
# 2   He has given the slogan of 'Jai Jawan Jai Kisa...
# 3                                                   -
# 4                First female Prime Minister of India
# 5   Oldest to become PM (81 years old) and first t...
# 6             Only PM who did not face the Parliament
# 7   The first lady who served as PM for the second...
# 8                Youngest to become PM (40 years old)
# 9   First PM to step down after a vote of no confi...
# 10              He belongs to  Samajwadi Janata Party
# 11                          First PM from South India
# 12                             PM for shortest tenure
# 13                          He belongs to  Janata Dal
# 14                                             ------
# 15   The first non-congress PM who completed a ful...
# 16                                      First Sikh PM
# 17  4th Prime Minister of India who served two con...
# 18  First non-congress PM with two consecutive ten...

# %% [markdown]
# Q10: Write s python program to display list of 50 Most expensive cars in the world (i.e. Company name, Model name and Price and Description) from https://www.motor1.com/ This task will be done in following steps:
#
# First get the webpage https://www.motor1.com/
# Then You have to click on the List option from Dropdown menu on left side.
# Then click on 50 most expensive cars in the world..
# Then scrap the mentioned data and make the Dataframe

# %%
driver=webdriver.Chrome(r"Chromedriver.exe")

# %%
url=" https://www.motor1.com/"
driver.get(url)

# %%
cl=driver.find_element(By.XPATH,'//div[@class="m1-hamburger-button"]')
cl.click()

# %%
listy=driver.find_element(By.XPATH,'/html/body/div[10]/div[7]/div[2]/div[1]/div[2]/div[1]/h3[1]')
listy.click()

# %%
exp=driver.find_element(By.XPATH,"//div[@class='text-box']/h3/a[contains(@href,'-new-cars-ever')]")
exp.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18028\537094751.py in <module>
# ----> 1 exp=driver.find_element(By.XPATH,"//div[@class='text-box']/h3/a[contains(@href,'-new-cars-ever')]")
#       2 exp.click()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     829             value = f'[name="{value}"]'
#     830
# --> 831         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     832
#     833     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     438         response = self.command_executor.execute(driver_command, params)
#     439         if response:
# --> 440             self.error_handler.check_response(response)
#     441             response["value"] = self._unwrap_value(response.get("value", None))
#     442             return response
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     243                 alert_text = value["alert"].get("text")
#     244             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245         raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@class='text-box']/h3/a[contains(@href,'-new-cars-ever')]"}
#   (Session info: chrome=114.0.5735.199)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00868893+48451]
# 	(No symbol) [0x007FB8A1]
# 	(No symbol) [0x00705058]
# 	(No symbol) [0x00730467]
# 	(No symbol) [0x0073069B]
# 	(No symbol) [0x0075DD92]
# 	(No symbol) [0x0074A304]
# 	(No symbol) [0x0075C482]
# 	(No symbol) [0x0074A0B6]
# 	(No symbol) [0x00727E08]
# 	(No symbol) [0x00728F2D]
# 	GetHandleVerifier [0x00AC8E3A+2540266]
# 	GetHandleVerifier [0x00B08959+2801161]
# 	GetHandleVerifier [0x00B0295C+2776588]
# 	GetHandleVerifier [0x008F2280+612144]
# 	(No symbol) [0x00804F6C]
# 	(No symbol) [0x008011D8]
# 	(No symbol) [0x008012BB]
# 	(No symbol) [0x007F4857]
# 	BaseThreadInitThunk [0x769F7D59+25]
# 	RtlInitializeExceptionChain [0x77E5B79B+107]
# 	RtlClearBits [0x77E5B71F+191]

# %%
cars = []
names_50expcars = driver.find_elements(By.XPATH,"//h3[@class='subheader']")
for i in names_50expcars:
        cars.append(i.text)
cars.pop()
# Out:
# 'Most Expensive Cars In The World'

# %%
prices = []
prices_50expcars = driver.find_elements(By.XPATH,"//strong")

for j in prices_50expcars:
        prices.append(j.text)
prices.pop(4)
# Out:
# 'Price: $1.7 Million'

# %%
print(len(cars),len(prices))
# Out:
# 50 50

# %%
most_expensive=pd.DataFrame({"NAME OF THE CAR":cars,"PRICE OF THE CAR IN ($)":prices})

# %%
most_expensive
# Out:
#                     NAME OF THE CAR      PRICE OF THE CAR IN ($)
# 0                     De Tomaso P72          Price: $1.3 Million
# 1                 Ferrari LaFerrari          Price: $1.4 Million
# 2                     Pagani Huayra          Price: $1.4 Million
# 3                      McLaren Elva
# 4                       Czinger 21C          Price: $1.7 Million
# 5                     Ferrari Monza          Price: $1.7 Million
# 6                Gordon Murray T.33          Price: $1.7 Million
# 7                 Koenigsegg Gemera          Price: $1.7 Million
# 8                       Zenvo TSR-S          Price: $1.7 Million
# 9                Hennessey Venom F5          Price: $1.8 Million
# 10                  Bentley Bacalar          Price: $1.9 Million
# 11    Hispano Suiza Carmen Boulogne          Price: $1.9 Million
# 12           Bentley Mulliner Batur          Price: $2.0 Million
# 13                     Deus Vayanne          Price: $2.0 Million
# 14                      SSC Tuatara         Price: $2.0 Million*
# 15                      Lotus Evija          Price: $2.1 Million
# 16              Aston Martin Vulcan          Price: $2.3 Million
# 17                       Delage D12          Price: $2.3 Million
# 18                McLaren Speedtail          Price: $2.3 Million
# 19                     Rimac Nevera          Price: $2.4 Million
# 20                    Pagani Utopia          Price: $2.5 Million
# 21             Pininfarina Battista          Price: $2.5 Million
# 22                Ferrari FXX K Evo          Price: $2.6 Million
# 23               Gordon Murray T.50          Price: $2.6 Million
# 24             Lamborghini Countach          Price: $2.6 Million
# 25         Mercedes-AMG Project One          Price: $2.7 Million
# 26              Aston Martin Victor          Price: $3.0 Million
# 27      Hennessey Venom F5 Roadster                 $3.0 Million
# 28                 Koenigsegg Jesko          Price: $3.0 Million
# 29            Aston Martin Valkyrie          Price: $3.2 Million
# 30        W Motors Lykan Hypersport          Price: $3.4 Million
# 31                    McLaren Solus                 $3.5 Million
# 32        Pagani Huayra Roadster BC          Price: $3.5 Million
# 33         Bugatti Chiron Pur Sport          Price: $3.6 Million
# 34                 Lamborghini Sian          Price: $3.6 million
# 35                 Koenigsegg CC850          Price: $3.7 Million
# 36  Bugatti Chiron Super Sport 300+          Price: $3.9 Million
# 37               Lamborghini Veneno          Price: $4.5 Million
# 38                   Bugatti Bolide          Price: $4.7 Million
# 39                  Bugatti Mistral          Price: $5.0 Million
# 40              Pagani Huayra Imola          Price: $5.4 Million
# 41                     Bugatti Divo          Price: $5.8 Million
# 42              SP Automotive Chaos          Price: $6.4 Million
# 43                 Pagani Codalunga          Price: $7.4 Million
# 44         Mercedes-Maybach Exelero          Price: $8.0 Million
# 45               Bugatti Centodieci          Price: $9.0 Million
# 46          Bugatti Chiron Profilée         Price: $10.8 Million
# 47             Rolls-Royce Sweptail         Price: $12.8 Million
# 48         Bugatti La Voiture Noire         Price: $13.4 Million
# 49           Rolls-Royce Boat Tail*  Price: $28.0 Million (est.)
